# %%
import numpy as np
import pandas as pd
import tabula

# %%
tabula.read_pdf("Data/Mak23.pdf", pages="all")
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'
# [   Unnamed: 0             Unnamed: 1  \
#  0         NaN                    NaN
#  1         NaN                    NaN
#  2         NaN                    NaN
#  3          No                 formid
#  4         NaN                    NaN
#  5           1   23APF412304454141015
#  6           2   23APF345674424112360
#  7           3  23APF1361730063122187
#  8           4   23APF519647933132646
#  9           5  23APF1481620160129238
#  10          6  23APF1501202078128326
#  11          7  23APF1139056282132364
#  12          8   23APF101396019107326
#  13          9   23APF515017899120808
#  14         10  23APF1672224247102423
#  15         11   23APF202185286140690
#  16         12   23APF231194390150185
#  17         13   23APF174935849136324
#  18         14   23APF324272143128932
#  19         15   23APF231927019128941
#  20         16  23APF1362423415106885
# ...

# %%
#import pandas as pd
import pandas as pd
obj = pd.Series([4,7,-5,3], index=["d", "b", "a", "c"])
obj
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj[obj>0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
obj *2
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
dict={"sarah":21,"josephine":22,"aaron":25,"steven":27}
names=pd.Series(dict)
names
# Out:
# sarah        21
# josephine    22
# aaron        25
# steven       27
# dtype: int64

# %%
#data frame
df=pd.DataFrame({"College": ["CEDAT", "CONAS", "CAES", "CoBAMS"],
                 "Budget": [123, 456, 789, 351],
                 "popn":[506,  452, 890, 986]})
df
# Out:
#   College  Budget  popn
# 0   CEDAT     123   506
# 1   CONAS     456   452
# 2    CAES     789   890
# 3  CoBAMS     351   986

# %%
df = pd.read_csv(d
